# %%
#importing packages
import numpy as np # data arrays
import pandas as pd # data structure and data analysis
import matplotlib as plt # data visualization
import datetime as dt # date time

# %%
#importing data set
df_15=pd.read_csv("C:/Users/deevy/Desktop/WHD/2015.csv")
df_16=pd.read_csv("C:/Users/deevy/Desktop/WHD/2016.csv")
df_17=pd.read_csv("C:/Users/deevy/Desktop/WHD/2017.csv")
df_18=pd.read_csv("C:/Users/deevy/Desktop/WHD/2018.csv")
df_19=pd.read_csv("C:/Users/deevy/Desktop/WHD/2019.csv")

# %%
#exploring datasets
df_15.head(3)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204

# %%
df_19.head(3)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# 2                      0.341

# %%
df_17.head(3)
# Out:
#    Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0   Norway               1            7.537      7.594445     7.479556
# 1  Denmark               2            7.522      7.581728     7.462272
# 2  Iceland               3            7.504      7.622030     7.385970
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 0    0.362012                       0.315964           2.277027
# 1    0.355280                       0.400770           2.313707
# 2    0.475540                       0.153527           2.322715

# %%
df_16.head(3)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# 2                   1.42666  1.18326                   0.86733  0.56624
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.44453     0.36171            2.73939
# ...

# %%
df_18.head(3)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# 2                      0.408

# %%
#we will be using the most recent data availabe that is for the years 2018 and 2019
#we will be finding relationships or correlations between each variable for both years

# %%
#obtaining the sum of missing data points per column and then displaying it
df_18_total=df_18.isnull().sum()
df_18_total[:]
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       1
# dtype: int64

# %%
df_19_total=df_19.isnull().sum()
df_19_total[:]
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %%
#finding out the basic information about the data
df_18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     155 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
df_19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
#renaming column names
df_18.columns=['Rank','Country','Happiness_Score','GDP_PerCapita','Social_Support','Healthy_life_expectancy','Freedom_to_make_life_choices','Generosity','Perceptions_of_corruption']

# %%
df_18.head(2)
# Out:
#    Rank  Country  Happiness_Score  GDP_PerCapita  Social_Support  \
# 0     1  Finland            7.632          1.305           1.592
# 1     2   Norway            7.594          1.456           1.582
#
#    Healthy_life_expectancy  Freedom_to_make_life_choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
#
#    Perceptions_of_corruption
# 0                      0.393
# 1                      0.340

# %%
df_19.columns=['Rank','Country','Happiness_Score','GDP_PerCapita','Social_Support','Healthy_life_expectancy','Freedom_to_make_life_choices','Generosity','Perceptions_of_corruption']
df_19.head(2)
# Out:
#    Rank  Country  Happiness_Score  GDP_PerCapita  Social_Support  \
# 0     1  Finland            7.769          1.340           1.587
# 1     2  Denmark            7.600          1.383           1.573
#
#    Healthy_life_expectancy  Freedom_to_make_life_choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
#
#    Perceptions_of_corruption
# 0                      0.393
# 1                      0.410

# %%
#Coulmns renamed for ease in doing our Analysis

# %%
#general statistics
df_18.describe()
# Out:
#              Rank  Happiness_Score  GDP_PerCapita  Social_Support  \
# count  156.000000       156.000000     156.000000      156.000000
# mean    78.500000         5.375917       0.891449        1.213237
# std     45.177428         1.119506       0.391921        0.302372
# min      1.000000         2.905000       0.000000        0.000000
# 25%     39.750000         4.453750       0.616250        1.066750
# 50%     78.500000         5.378000       0.949500        1.255000
# 75%    117.250000         6.168500       1.197750        1.463000
# max    156.000000         7.632000       2.096000        1.644000
#
#        Healthy_life_expectancy  Freedom_to_make_life_choices  Generosity  \
# count               156.000000                    156.000000  156.000000
# mean                  0.597346                      0.454506    0.181006
# std                   0.247579                      0.162424    0.098471
# min                   0.000000                      0.000000    0.000000
# ...

# %%
df_19.describe()
# Out:
#              Rank  Happiness_Score  GDP_PerCapita  Social_Support  \
# count  156.000000       156.000000     156.000000      156.000000
# mean    78.500000         5.407096       0.905147        1.208814
# std     45.177428         1.113120       0.398389        0.299191
# min      1.000000         2.853000       0.000000        0.000000
# 25%     39.750000         4.544500       0.602750        1.055750
# 50%     78.500000         5.379500       0.960000        1.271500
# 75%    117.250000         6.184500       1.232500        1.452500
# max    156.000000         7.769000       1.684000        1.624000
#
#        Healthy_life_expectancy  Freedom_to_make_life_choices  Generosity  \
# count               156.000000                    156.000000  156.000000
# mean                  0.725244                      0.392571    0.184846
# std                   0.242124                      0.143289    0.095254
# min                   0.000000                      0.000000    0.000000
# ...

# %%
import matplotlib.pyplot as plt

# plotting scatter plot 2018
plt.style.use("default")
plt.figure(figsize=(5,5)) # specify size of the chart
plt.scatter(df_18.Happiness_Score, df_18.Rank, 
            alpha = 0.8, c = df_18.Rank, 
            cmap = "Spectral_r")

# add annotations and visuals
mean_Happiness_Score = 5.375917
plt.colorbar(orientation = "vertical")
plt.axvline(mean_Happiness_Score, color = "green", label = "Mean Happiness Score")
plt.xlabel("Happiness Score")
plt.ylabel("Rank")
plt.title("Rank vs Happiness Score 2018")
plt.grid(True)
plt.legend()
plt.show()

# plotting scatter plot 2019
plt.style.use("default")
plt.figure(figsize=(5,5)) # specify size of the chart
plt.scatter(df_19.Happiness_Score, df_19.Rank, 
            alpha = 0.8, c = df_19.Rank, 
            cmap = "Spectral_r")

# add annotations and visuals
mean_Happiness_Score = 5.407096
plt.colorbar(orientation = "vertical")
plt.axvline(mean_Happiness_Score, color = "green", label = "Mean Happiness Score")
plt.xlabel("Happiness Score")
plt.ylabel("Rank")
plt.title("Rank vs Happiness Score 2019")
plt.grid(True)
plt.legend()
plt.show()

# %%
# plotting scatter plot 2018
plt.style.use("default")
plt.figure(figsize=(5,5)) # specify size of the chart
plt.scatter(df_18.Happiness_Score, df_18.Social_Support, 
            alpha = 0.8, c = df_18.Social_Support, 
            cmap = "Spectral")

# add annotations and visuals
mean_Happiness_Score = 5.375917
mean_Social_Support = 1.213237
plt.colorbar(orientation = "vertical")
plt.axvline(mean_Happiness_Score, color = "green", label = "Mean Happiness Score")
plt.axhline(mean_Social_Support, color = "blue", label = "Mean Social Support")
plt.xlabel("Happiness Score")
plt.ylabel("Social Support")
plt.title("Social Support vs Happiness Score 2018")
plt.grid(True)
plt.legend()
plt.show()



# plotting scatter plot 2019
plt.style.use("default")
plt.figure(figsize=(5,5)) # specify size of the chart
plt.scatter(df_19.Happiness_Score, df_19.Social_Support, 
            alpha = 0.8, c = df_19.Social_Support, 
            cmap = "Spectral")

# add annotations and visuals
mean_Happiness_Score = 5.407096
mean_Social_Support = 1.208814
plt.colorbar(orientation = "vertical")
plt.axvline(mean_Happiness_Score, color = "green", label = "Mean Happiness Score")
plt.axhline(mean_Social_Support, color = "blue", label = "Mean Social Support")
plt.xlabel("Happiness Score")
plt.ylabel("Social Support")
plt.title("Social Support vs Happiness Score 2019")
plt.grid(True)
plt.legend()
plt.show()

# %%
# plotting scatter plot 2018
plt.style.use("default")
plt.figure(figsize=(5,5)) # specify size of the chart
plt.scatter(df_18.Happiness_Score, df_18.GDP_PerCapita, 
            alpha = 0.8, c = df_18.GDP_PerCapita, 
            cmap = "Spectral")

# add annotations and visuals
mean_Happiness_Score = 5.375917
mean_GDP_PerCapita = 0.891449
plt.colorbar(orientation = "vertical")
plt.axvline(mean_Happiness_Score, color = "green", label = "Mean Happiness Score")
plt.axhline(mean_GDP_PerCapita, color = "blue", label = "Mean GDP_PerCapita")
plt.xlabel("Happiness Score")
plt.ylabel("GDP per Capita")
plt.title("GDP per Capita vs Happiness Score 2018")
plt.grid(True)
plt.legend()
plt.show()



# plotting scatter plot 2019
plt.style.use("default")
plt.figure(figsize=(5,5)) # specify size of the chart
plt.scatter(df_19.Happiness_Score, df_19.GDP_PerCapita, 
            alpha = 0.8, c = df_19.GDP_PerCapita, 
            cmap = "Spectral")

# add annotations and visuals
mean_Happiness_Score = 5.407096
mean_GDP_PerCapita = 0.905147
plt.colorbar(orientation = "vertical")
plt.axvline(mean_Happiness_Score, color = "green", label = "Mean Happiness Score")
plt.axhline(mean_GDP_PerCapita, color = "blue", label = "Mean GDP_PerCapita")
plt.xlabel("Happiness Score")
plt.ylabel("GDP per Capita")
plt.title("GDP per Capita vs Happiness Score 2019")
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.style.use("default")
plt.figure(figsize=(5,5)) # specify size of the chart
plt.scatter(df_18.Happiness_Score, df_18.Perceptions_of_corruption, 
            alpha = 0.8, c = df_18.Perceptions_of_corruption, 
            cmap = "Spectral")

# add annotations and visuals
mean_Happiness_Score = 5.375917
mean_Perceptions_of_corruption = 0.112000
plt.colorbar(orientation = "vertical")
plt.axvline(mean_Happiness_Score, color = "green", label = "Mean Happiness Score")
plt.axhline(mean_Perceptions_of_corruption, color = "blue", label = "Mean Perceptions of corruption")
plt.xlabel("Happiness Score")
plt.ylabel("Perceptions of corruption")
plt.title("Perceptions of corruption vs Happiness Score 2018")
plt.grid(True)
plt.legend()
plt.show()



# plotting scatter plot 2019
plt.style.use("default")
plt.figure(figsize=(5,5)) # specify size of the chart
plt.scatter(df_19.Happiness_Score, df_19.Perceptions_of_corruption, 
            alpha = 0.8, c = df_19.Perceptions_of_corruption, 
            cmap = "Spectral")

# add annotations and visuals
mean_Happiness_Score = 5.407096
mean_Perceptions_of_corruption = 0.110603
plt.colorbar(orientation = "vertical")
plt.axvline(mean_Happiness_Score, color = "green", label = "Mean Happiness Score")
plt.axhline(mean_Perceptions_of_corruption, color = "blue", label = "Mean Perceptions of corruption")
plt.xlabel("Happiness Score")
plt.ylabel("Perceptions of corruption")
plt.title("Perceptions of corruption vs Happiness Score 2019")
plt.grid(True)
plt.legend()
plt.show()

# %%
# plotting scatter plot 2018
plt.style.use("default")
plt.figure(figsize=(5,5)) # specify size of the chart
plt.scatter(df_18.Rank, df_18.GDP_PerCapita, 
            alpha = 0.8, c = df_18.GDP_PerCapita, 
            cmap = "Spectral")

# add annotations and visuals
mean_GDP_PerCapita = 0.891449
plt.colorbar(orientation = "vertical")
plt.axhline(mean_GDP_PerCapita, color = "blue", label = "Mean GDP_PerCapita")
plt.xlabel("Rank")
plt.ylabel("GDP per Capita")
plt.title("GDP per Capita vs Rank 2018")
plt.grid(True)
plt.legend()
plt.show()



# plotting scatter plot 2019
plt.style.use("default")
plt.figure(figsize=(5,5)) # specify size of the chart
plt.scatter(df_19.Rank, df_19.GDP_PerCapita, 
            alpha = 0.8, c = df_19.GDP_PerCapita, 
            cmap = "Spectral")

# add annotations and visuals
mean_GDP_PerCapita = 0.905147
plt.colorbar(orientation = "vertical")
plt.axhline(mean_GDP_PerCapita, color = "blue", label = "Mean GDP_PerCapita")
plt.xlabel("Rank")
plt.ylabel("GDP per Capita")
plt.title("GDP per Capita vs Rank 2019")
plt.grid(True)
plt.legend()
plt.show()

# %%
import seaborn as sns
df_18_c=df_18.drop(['Rank','Country'], axis=1)
df_18_c.head(1)
# Out:
#    Happiness_Score  GDP_PerCapita  Social_Support  Healthy_life_expectancy  \
# 0            7.632          1.305           1.592                    0.874
#
#    Freedom_to_make_life_choices  Generosity  Perceptions_of_corruption
# 0                         0.681       0.202                      0.393

# %%
# plotting correlation heatmap
dataplot = sns.heatmap(df_18_c.corr(), cmap="Blues", annot=True)
plt.title('The figure shows the correlations between variables. However, these correlations does not imply causations. Year :2018')
  
# displaying heatmap
plt.show()

# %%
df_19_c=df_19.drop(['Rank','Country'], axis=1)
df_19_c.head(1)
# Out:
#    Happiness_Score  GDP_PerCapita  Social_Support  Healthy_life_expectancy  \
# 0            7.769           1.34           1.587                    0.986
#
#    Freedom_to_make_life_choices  Generosity  Perceptions_of_corruption
# 0                         0.596       0.153                      0.393

# %%
# plotting correlation heatmap
dataplot = sns.heatmap(df_19_c.corr(), cmap="Blues", annot=True)
plt.title('The figure shows the correlations between variables.However, these correlations does not imply causations. Year :2019')
  
# displaying heatmap
plt.show()

# %%
#In the final step, we will be delivering our insights and providing recommendations based on our analysis.
